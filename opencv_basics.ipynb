# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("C:\\Users\\shaik\\OneDrive\\Desktop\\Age & gender detector\\images\\project1.jpg")
plt.imshow(img1)

# %% [markdown]
# Arthematic operations

# %%
#img2=cv2.imread("C:\\Users\\shaik\\OneDrive\\Desktop\\Age & gender detector\\images\\project 2.jpg",0)
#plt.imshow(img2)
img2=cv2.imread("C:\\Users\\shaik\\OneDrive\\Desktop\\Age & gender detector\\images\\project1.jpg")
plt.imshow(img2)

# %%
img3=cv2.imread("C:\\Users\\shaik\\OneDrive\\Desktop\\Age & gender detector\\images\\project 2.jpg")
plt.imshow(img3)

# %%
result=img1+img2
plt.imshow(result)

# %% [markdown]
# Subtraction

# %%
result=img1-img2
plt.imshow(result)

# %%
result=img1*img2
plt.imshow(result)

# %%
result=img1/img2
plt.imshow(result)
# Out:
# C:\Users\shaik\AppData\Local\Temp\ipykernel_2872\1580248168.py:1: RuntimeWarning: invalid value encountered in divide
#   result=img1/img2

# %%
img1=cv2.imread("C:\\Users\\shaik\\OneDrive\\Desktop\\Age & gender detector\\images\\project1.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show()

# %%
(height,width)=img3.shape[0:2]
zoom=cv2.resize(img3,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img3,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %%
import numpy as np

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.imshow(dst)
